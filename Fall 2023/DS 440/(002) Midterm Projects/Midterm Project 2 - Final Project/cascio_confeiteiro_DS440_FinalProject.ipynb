# %% [markdown]
# # DS-440 Final Project

# %% [markdown]
# |  Item | Info.   |
# |------|------|
# | Group | Antonio Cascio & Krystian Confeiteiro |
# | Professor | Dr. Jack |
# | Course | DS 440 - 01DB|
# | Assignment | Final Project ([link](https://erau.instructure.com/courses/163647/assignments/3331626)) |
# | Date Created: | 11/09/2023 |
# | Date Due: | **TBD** |
# | Last Edited: | 11/09/2023 |

# %% [markdown]
# # The Code

# %% [markdown]
# ## Imports & Google Drive Mount

# %%
import matplotlib.pyplot as plt
from google.colab import drive
import pandas as pd
import numpy as np
import warnings

# ignore warning and mount Google Drive
warnings.filterwarnings("ignore")
drive.mount("/content/drive", force_remount=True)
ROOT = "/content/drive/MyDrive/006_Courses/DS_440/000_Midterm_Projects/Midterm_2_final_project"

# %% [markdown]
# ## Read & Prepare Data
