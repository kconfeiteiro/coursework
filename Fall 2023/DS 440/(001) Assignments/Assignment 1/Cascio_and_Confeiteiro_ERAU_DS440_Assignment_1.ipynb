# %% [markdown]
# # Assignment Details
# - Group members:
#     - Antonio Cascio & Krystian Ojeda Confeiteiro
# - Course: DS 440
# - Professor: Dr. Jack
# - Date: 09/06/2023
#
# # Assignment Checklist
# - [x] Create colab notebook
# - [x] Change filename
# - [x] Create cell and insert "Question 1"
# - [x] Write code to print current date and time
# - [x] Execute cell
# - [x] Save `.ipynb` file to OneDrive
# - [x] Submit link to Colab Notebook

# %% [markdown]
# #  Question 1

# %%
from datetime import datetime

today = datetime.now()
longdateformat = today.strftime("%B %d, %Y")
print("Today's date is {}.".format(longdateformat))
# Out:
# Today's date is September 07, 2023.
