# %%
# @title Enter your name { display-mode: "form" }
Your_Name = "" # @param {type:"string"}

# %% [markdown]
# # Hertzsprung-Russell Diagram

# %% [markdown]
# In this portfolio, you will create your own HR Diagram, similar to the one below.
#
# ![HRD.png](data:image/png;base64,...)
#
# To do this you will need to download data from the <a href="https://www.unige.ch/sciences/astro/evolution/en/research/geneva-grids-stellar-evolution-models/#grids92">Geneva Stellar Evolutionary code </a>. This database provides a model grid of stellar parameters in different stages of a stars evolution.
#
# The different models contain information for
#
# * isochrones (**same age**, different masses) and
# * evolutionary tracks (**one mass** over time).

# %% [markdown]
# ## Import relevant libraries
#
# Here we provide some of the libraries that need to be read in to be able to execute our code. Remember that:
#     1- **NumPy** is a fundamental package of Python. It allows for a wide range of  data
#         types and data manipulation capapbilities. To use it you will call it simply as
#         **np**.
#     2- **Matplolib** is a Python 2D plotting library. We are only loading the Pyplot
#         capabilties, which provide a collection of command that make matplotlib work like
#         *MATLAB*.
#     3- `%matplotlib notebook` allows for interactive plotting.
#
# Include any other libraries that you may find useful.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Getting the Data
#
# For this assignment, we will use Grids of Stellar Models with Rotation, primarily using solar abundance models (Z = 0.014).
#
# $\color{blue}{\text{Download the tracks and isochrone grid on}}$ <a href = "http://vizier.u-strasbg.fr/viz-bin/VizieR-3?-source=J/A%2bA/537/A146&-out.max=50&-out.form=HTML%20Table&-out.add=_r&-out.add=_RAJ,_DEJ&-sort=_r&-oc.form=sexa"> VizieR </a>.
#
# To limit the output, you will need to specify:
#
# * Z = 0.014
# * Specify models with rotation
# * For isochrones: enter the age as $\log (t)$ in years. Example: for a 3 Myr isochrone, enter 6.5
# * For evolutionary tracks: enter the initial mass in solar masses
# * Output the information in some plain text/ASCII friendly format (e.g. Tab separated, ; separated, ascii text/plain) that will be downloaded. The default is an HTML table
#
# Once you have downloaded the relevant files, make sure to add them to your content folder.

# %% [markdown]
# **Q1:** $\color{gray}{\text{What information from the models do you need to build your ZAMS?}}$

# %%
# @title Q1 { display-mode: "form" }
Answer = "" # @param {type:"string"}

# %%
# Read in the relevant data from the files

# %% [markdown]
# ## The Sun
#
# **Q2:** $\color{gray}{\text{What information about the Sun do you need to include it on your HR-Diagram? Provide your reference for this information.}}$

# %%
# @title Q2 { display-mode: "form" }
Answer = "" # @param {type:"string"}

# %%
#Include the relevant parameters of the Sun to plot. Remember that the values must be in the
#form of an array.

lum_sun =
teff_sun =

# %% [markdown]
# ## Assignment
#
# With this information, I would like you to create one H-R diagram with the following:
#
# 1. The ZAMS over the mass range possible with the models (0.8-120 $M_{\odot}$)
# 2. Denote where the Sun is located on the H-R diagram
# 3. Isochrones over a sampling of the available ages (e.g. $\log (t)$ = 6.5, 7.5, 8.5, 9.5, 10.1 yr), showing how the Main Sequence changes over time.
# 4. Choose the evolutionary track of one star with M $< 8~M_{\odot}$ and another with M $ > 8~M_{\odot}$, plot and label the tracks of these stars. Some accepted values for masses are: 0.8, 0.9, 1, 1.1, 1.25, 1.35, 1.5, 3, 4, 7, 20, 25, 32, 85, 120 $ M_{\odot}$.
# 5. Make sure to clearly label your figure, include a legend and write a caption. Include in the caption the evolutionary stages for the two stars you chose from part #4.
# 6. Make sure you properly comment your code. This is expected of any future assignment that requires the use of coding.
# 7. Make sure to include any references you use in creating this plot (e.g. solar values for luminosity and temperature).

# %%
# Create the appropriate arrays of the data you will use to plot

# %%
# Create your figure
